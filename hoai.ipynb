# %%
import os
import numpy as np
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#PATH = '../finanz_vs_news'
PATH = 'C:/Users/Hoai/finanz_vs_news/'

# %%
# example how to read the daily stock rates with PATH
df_stock = pd.read_csv(PATH+'StocksDaily/ALL_2007-01-01_2017-10-16.csv')
df_stock_min = pd.read_csv(PATH+'StocksMinute/AA_20090101_20090630.csv')
df = df_stock

# %%
df_stock.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2007-01-03  25.028612  25.379112  24.356224  24.535049  23.154404
# 1  2007-01-04  24.535049  24.749641  23.934191  24.613733  23.228655
# 2  2007-01-05  24.535049  24.606581  24.320457  24.384836  23.012638
# 3  2007-01-08  24.306152  24.377682  24.091558  24.298998  22.931633
# 4  2007-01-09  24.377682  24.549356  24.055794  24.327610  22.958633
#
#       Volume ticker
# 0  3599200.0      A
# 1  2899000.0      A
# 2  3741800.0      A
# 3  2176900.0      A
# 4  1937900.0      A

# %%
df_stock['ticker'].nunique()
# Out:
# 429

# %%
pd.unique(df_stock['ticker'].values.ravel('K'))
# Out:
# array(['A', 'AAPL', 'ABBV', 'ABC', 'ABK', 'ABT', 'ACN', 'ADI', 'ADP',
#        'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET', 'AFL', 'AGN', 'AIG',
#        'AIV', 'AIZ', 'AKAM', 'AKS', 'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN',
#        'AMZN', 'AN', 'ANF', 'AON', 'APA', 'APC', 'APD', 'APH', 'ATI',
#        'AVB', 'AVGO', 'AVP', 'AVY', 'AXP', 'AYE', 'AZO', 'BA', 'BAC',
#        'BAX', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BIG', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMS', 'BMY', 'BSX', 'BTU', 'BWA', 'CA', 'CAG', 'CAH',
#        'CB', 'CBE', 'CBG', 'CBS', 'CCI', 'CCK', 'CCL', 'CEG', 'CF', 'CHK',
#        'CHRW', 'CI', 'CINF', 'CL', 'CLF', 'CLX', 'CMA', 'CMCSA', 'CME',
#        'CMG', 'CMI', 'CMS', 'CNP', 'CNX', 'COF', 'COG', 'COH', 'COP',
#        'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTL', 'CTSH', 'CTXS', 'CVS',
#        'CVX', 'D', 'DAL', 'DE', 'DF', 'DFS', 'DG', 'DGX', 'DHR', 'DISCA',
#        'DNR', 'DO', 'DOV', 'DOW', 'DPS', 'DRI', 'DTE', 'DTV', 'DUK', 'DVA',
# ...

# %%
df_stock_min.head()
# Out:
#   <TICKER>  <PER>    <DATE>  <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>   <VOL>
# 0       AA      1  20090601   23100  9.5200  9.5500  9.5000   9.5484   13370
# 1       AA      1  20090601   23200  9.5499  9.5500  9.4988   9.4988   41796
# 2       AA      1  20090601   23300  9.5000  9.5199  9.4100   9.4100  142287
# 3       AA      1  20090601   23400  9.4200  9.4200  9.3700   9.3800   29490
# 4       AA      1  20090601   23500  9.3900  9.4000  9.3200   9.3500   97091

# %%
df_stock["Adj Close"].plot(grid = True) # Plot the adjusted closing price of AAPL

# %%
df_A = df_stock[df_stock['ticker'] == 'A']

# %%
#df_A = df_stock[df_stock['ticker'] == c]
df_A["Adj Close"].plot(grid = True)

print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a60bcd956b6b> in <module>()
#       2 df_A["Adj Close"].plot(grid = True)
#       3
# ----> 4 print(c)
#
# NameError: name 'c' is not defined

# %%
df_A["Open"].plot(grid = True)

# %%
df_A["Low"].plot(grid = True)

# %%
df_A["Volume"].plot(grid = True)

# %%
plt.plot(df_A['Date'], df_A['Volume'])
plt.show()

# %%
df = cf.datagen.lines()

py.iplot([{
    'x': df.index,
    'y': df[col],
    'name': col
}  for col in df.columns], filename='cufflinks/simple-line')

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot
print (__version__) # requires version >= 1.9.0
init_notebook_mode(connected=True)

import plotly.offline as py
import plotly.graph_objs as go
# Out:
# 3.3.0
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff
from datetime import datetime
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df_percompany = df_A

trace = go.Candlestick(x=df_percompany.Date,
                       open=df_percompany.Open,
                       high=df_percompany.High,
                       low=df_percompany.Low,
                       close=df_percompany.Close)
data = [trace]

py.iplot(data, filename='one company')
# Out:
# <div id="e7255529-5ae0-4f60-b0b0-13bb887cfcc3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e7255529-5ae0-4f60-b0b0-13bb887cfcc3", [{"close": [24.535049, 24.613733, 24.384836, 24.298998, 24.32761, 24.105865, 24.105865, 24.034334, 23.991417, 23.512159, 23.06867, 23.46209, 23.297567, 23.397711, 23.32618, 22.93276, 23.154507, 22.88269, 22.889843, 22.889843, 23.025751, 22.610872, 22.76824, 22.889843, 23.297567, 23.369099, 23.361946, 23.311874, 23.590843, 23.562231, 24.198856, 23.44063, 23.240343, 23.426323, 23.60515, 23.798283, 23.805437, 22.968527, 22.711016, 22.489271, 21.974249, 21.952789000000006, 22.052933, 22.017168, 22.703863, 22.718168, 22.989986, 22.653791, 22.889843, 22.675251, 22.711016, 22.782547, 22.93276, 22.95422, 23.311874, 23.762518, 23.848354, 24.055794, 23.948498, 24.113018, 24.09
# ...

# %%
df_percompany
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2007-01-03  25.028612  25.379112  24.356224  24.535049  23.154404
# 1     2007-01-04  24.535049  24.749641  23.934191  24.613733  23.228655
# 2     2007-01-05  24.535049  24.606581  24.320457  24.384836  23.012638
# 3     2007-01-08  24.306152  24.377682  24.091558  24.298998  22.931633
# 4     2007-01-09  24.377682  24.549356  24.055794  24.327610  22.958633
# 5     2007-01-10  24.349070  24.349070  23.869814  24.105865  22.749365
# 6     2007-01-11  24.198856  24.349070  23.855509  24.105865  22.749365
# 7     2007-01-12  24.084406  24.349070  23.991417  24.034334  22.681862
# 8     2007-01-16  23.969957  24.270386  23.848354  23.991417  22.641356
# 9     2007-01-17  23.912733  23.948498  23.433475  23.512159  22.189075
# 10    2007-01-18  23.426323  23.454935  22.818312  23.068670  21.770538
# 11    2007-01-19  23.140200  23.562231  23.118742  23.462090  22.141819
# ...

# %%
df = df_A

trace = go.Candlestick(x=df.Date,
                       open=df.Open,
                       high=df.High,
                       low=df.Low,
                       close=df.Close)
data = [trace]

py.iplot(data, filename='all indicators')
# Out:
# <div id="8af99a19-edc8-468b-be86-1fbfdde51fec" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8af99a19-edc8-468b-be86-1fbfdde51fec", [{"close": [24.535049, 24.613733, 24.384836, 24.298998, 24.32761, 24.105865, 24.105865, 24.034334, 23.991417, 23.512159, 23.06867, 23.46209, 23.297567, 23.397711, 23.32618, 22.93276, 23.154507, 22.88269, 22.889843, 22.889843, 23.025751, 22.610872, 22.76824, 22.889843, 23.297567, 23.369099, 23.361946, 23.311874, 23.590843, 23.562231, 24.198856, 23.44063, 23.240343, 23.426323, 23.60515, 23.798283, 23.805437, 22.968527, 22.711016, 22.489271, 21.974249, 21.952789000000006, 22.052933, 22.017168, 22.703863, 22.718168, 22.989986, 22.653791, 22.889843, 22.675251, 22.711016, 22.782547, 22.93276, 22.95422, 23.311874, 23.762518, 23.848354, 24.055794, 23.948498, 24.113018, 24.09
# ...

# %%
data
# Out:
# [Candlestick({
#      'close': array([ 24.535049,  24.613733,  24.384836, ...,  67.540001,  66.989998,
#                       66.910004]),
#      'high': array([ 25.379112,  24.749641,  24.606581, ...,  67.599998,  67.82    ,
#                      67.370003]),
#      'low': array([ 24.356224,  23.934191,  24.320457, ...,  66.540001,  66.889999,
#                     66.769997]),
#      'open': array([ 25.028612,  24.535049,  24.535049, ...,  66.650002,  67.629997,
#                      67.199997]),
#      'x': array(['2007-01-03', '2007-01-04', '2007-01-05', ..., '2017-10-12',
#                  '2017-10-13', '2017-10-16'], dtype=object)
#  })]

# %%
two_comps = ['A','AAPL']
param = 'Open'
#print(two_comps[0])

#df_twocomps = df.loc[df['ticker'].isin(two_comps)]
df_compA = df.loc[df['ticker'] == 'A']
df_compA = df_compA[['Date', param]]
df_compB =df.loc[df['ticker'] == 'AAPL']
df_compB = df_compB[['Date', param]]
#df_compB['OpenB'] = df_compB['Open']

# %%
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2007-01-03  25.028612  25.379112  24.356224  24.535049  23.154404
# 1    2007-01-04  24.535049  24.749641  23.934191  24.613733  23.228655
# 2    2007-01-05  24.535049  24.606581  24.320457  24.384836  23.012638
# 3    2007-01-08  24.306152  24.377682  24.091558  24.298998  22.931633
# 4    2007-01-09  24.377682  24.549356  24.055794  24.327610  22.958633
# 5    2007-01-10  24.349070  24.349070  23.869814  24.105865  22.749365
# 6    2007-01-11  24.198856  24.349070  23.855509  24.105865  22.749365
# 7    2007-01-12  24.084406  24.349070  23.991417  24.034334  22.681862
# 8    2007-01-16  23.969957  24.270386  23.848354  23.991417  22.641356
# 9    2007-01-17  23.912733  23.948498  23.433475  23.512159  22.189075
# 10   2007-01-18  23.426323  23.454935  22.818312  23.068670  21.770538
# 11   2007-01-19  23.140200  23.562231  23.118742  23.462090  22.141819
# ...

# %%
df_compA
# Out:
#            Date       Open
# 0    2007-01-03  25.028612
# 1    2007-01-04  24.535049
# 2    2007-01-05  24.535049
# 3    2007-01-08  24.306152
# 4    2007-01-09  24.377682
# 5    2007-01-10  24.349070
# 6    2007-01-11  24.198856
# 7    2007-01-12  24.084406
# 8    2007-01-16  23.969957
# 9    2007-01-17  23.912733
# 10   2007-01-18  23.426323
# 11   2007-01-19  23.140200
# 12   2007-01-22  23.369099
# 13   2007-01-23  23.168812
# 14   2007-01-24  23.397711
# 15   2007-01-25  23.311874
# 16   2007-01-26  22.889843
# 17   2007-01-29  23.075823
# 18   2007-01-30  22.882690
# 19   2007-01-31  22.889843
# 20   2007-02-01  23.011444
# 21   2007-02-02  23.082975
# 22   2007-02-05  22.632332
# 23   2007-02-06  22.975679
# 24   2007-02-07  22.925608
# 25   2007-02-08  23.211731
# 26   2007-02-09  23.361946
# 27   2007-02-12  23.333334
# 28   2007-02-13  23.361946
# 29   2007-02-14  23.497854
# ...         ...        ...
# 2687 2017-09-05  64.019997
# 2688 2017-09-06  64.559998
# ...

# %%
two_comps = ['A','AAPL']
param = 'Open'
#print(two_comps[0])
df_compB = df_stock
#df_twocomps = df.loc[df['ticker'].isin(two_comps)]
df_compA = df.loc[df['ticker'] == 'A']
df_compA = df_compA[['Date', param]]

df_compA
# Out:
#            Date       Open
# 0    2007-01-03  25.028612
# 1    2007-01-04  24.535049
# 2    2007-01-05  24.535049
# 3    2007-01-08  24.306152
# 4    2007-01-09  24.377682
# 5    2007-01-10  24.349070
# 6    2007-01-11  24.198856
# 7    2007-01-12  24.084406
# 8    2007-01-16  23.969957
# 9    2007-01-17  23.912733
# 10   2007-01-18  23.426323
# 11   2007-01-19  23.140200
# 12   2007-01-22  23.369099
# 13   2007-01-23  23.168812
# 14   2007-01-24  23.397711
# 15   2007-01-25  23.311874
# 16   2007-01-26  22.889843
# 17   2007-01-29  23.075823
# 18   2007-01-30  22.882690
# 19   2007-01-31  22.889843
# 20   2007-02-01  23.011444
# 21   2007-02-02  23.082975
# 22   2007-02-05  22.632332
# 23   2007-02-06  22.975679
# 24   2007-02-07  22.925608
# 25   2007-02-08  23.211731
# 26   2007-02-09  23.361946
# 27   2007-02-12  23.333334
# 28   2007-02-13  23.361946
# 29   2007-02-14  23.497854
# ...         ...        ...
# 2687 2017-09-05  64.019997
# 2688 2017-09-06  64.559998
# ...

# %%
df_compB
# Out:
#                Date       Open       High        Low      Close  Adj Close  \
# 0        2007-01-03  25.028612  25.379112  24.356224  24.535049  23.154404
# 1        2007-01-04  24.535049  24.749641  23.934191  24.613733  23.228655
# 2        2007-01-05  24.535049  24.606581  24.320457  24.384836  23.012638
# 3        2007-01-08  24.306152  24.377682  24.091558  24.298998  22.931633
# 4        2007-01-09  24.377682  24.549356  24.055794  24.327610  22.958633
# 5        2007-01-10  24.349070  24.349070  23.869814  24.105865  22.749365
# 6        2007-01-11  24.198856  24.349070  23.855509  24.105865  22.749365
# 7        2007-01-12  24.084406  24.349070  23.991417  24.034334  22.681862
# 8        2007-01-16  23.969957  24.270386  23.848354  23.991417  22.641356
# 9        2007-01-17  23.912733  23.948498  23.433475  23.512159  22.189075
# 10       2007-01-18  23.426323  23.454935  22.818312  23.068670  21.770538
# ...

# %%
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2007-01-03  25.028612  25.379112  24.356224  24.535049  23.154404
# 1    2007-01-04  24.535049  24.749641  23.934191  24.613733  23.228655
# 2    2007-01-05  24.535049  24.606581  24.320457  24.384836  23.012638
# 3    2007-01-08  24.306152  24.377682  24.091558  24.298998  22.931633
# 4    2007-01-09  24.377682  24.549356  24.055794  24.327610  22.958633
# 5    2007-01-10  24.349070  24.349070  23.869814  24.105865  22.749365
# 6    2007-01-11  24.198856  24.349070  23.855509  24.105865  22.749365
# 7    2007-01-12  24.084406  24.349070  23.991417  24.034334  22.681862
# 8    2007-01-16  23.969957  24.270386  23.848354  23.991417  22.641356
# 9    2007-01-17  23.912733  23.948498  23.433475  23.512159  22.189075
# 10   2007-01-18  23.426323  23.454935  22.818312  23.068670  21.770538
# 11   2007-01-19  23.140200  23.562231  23.118742  23.462090  22.141819
# ...

# %%
df_compB = df_compB.loc[df_compB['ticker'] == 'AAPL']

# %%
df_compB = df_compB[['Date', param]]
#df_compB['OpenB'] = df_compB['Open']

df_compB.rename(index=str, columns={"Date": "Date", "Open": "openb"}, inplace=True)
df_compA.rename(index=str, columns={"Date": "Date", "Open": "Opena"}, inplace=True)
df_compA.head()


df_twos = df_compA.join(df_compB.set_index('Date'), on='Date')

# %%
df_compB.head()
# Out:
#             Date      openb
# 2717  2007-01-03  12.327143
# 2718  2007-01-04  12.007143
# 2719  2007-01-05  12.252857
# 2720  2007-01-08  12.280000
# 2721  2007-01-09  12.350000

# %%
df_twos
# Out:
#            Date      Opena  openb
# 0    2007-01-03  25.028612    NaN
# 1    2007-01-04  24.535049    NaN
# 2    2007-01-05  24.535049    NaN
# 3    2007-01-08  24.306152    NaN
# 4    2007-01-09  24.377682    NaN
# 5    2007-01-10  24.349070    NaN
# 6    2007-01-11  24.198856    NaN
# 7    2007-01-12  24.084406    NaN
# 8    2007-01-16  23.969957    NaN
# 9    2007-01-17  23.912733    NaN
# 10   2007-01-18  23.426323    NaN
# 11   2007-01-19  23.140200    NaN
# 12   2007-01-22  23.369099    NaN
# 13   2007-01-23  23.168812    NaN
# 14   2007-01-24  23.397711    NaN
# 15   2007-01-25  23.311874    NaN
# 16   2007-01-26  22.889843    NaN
# 17   2007-01-29  23.075823    NaN
# 18   2007-01-30  22.882690    NaN
# 19   2007-01-31  22.889843    NaN
# 20   2007-02-01  23.011444    NaN
# 21   2007-02-02  23.082975    NaN
# 22   2007-02-05  22.632332    NaN
# 23   2007-02-06  22.975679    NaN
# 24   2007-02-07  22.925608    NaN
# 25   2007-02-08  23.211731    NaN
# ...

# %%
trace0 = go.Scatter(
    x = df_twos['Date'],
    y = df_twos['opena'],
    mode = 'lines',
    name = 'lines'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda2\envs\dfinehack\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'opena'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-173-182fcedb9e67> in <module>()
#       2 trace0 = go.Scatter(
# ...

# %%
data = [trace0]

data
# Out:
# [Scatter({
#      'mode': 'lines',
#      'name': 'lines',
#      'x': array([datetime.datetime(2007, 1, 3, 0, 0), datetime.datetime(2007, 1, 4, 0, 0),
#                  datetime.datetime(2007, 1, 5, 0, 0), ...,
#                  datetime.datetime(2017, 10, 12, 0, 0),
#                  datetime.datetime(2017, 10, 13, 0, 0),
#                  datetime.datetime(2017, 10, 16, 0, 0)], dtype=object),
#      'y': array([ nan,  nan,  nan, ...,  nan,  nan,  nan])
#  })]

# %%
py.iplot(data, filename='line-mode')
# Out:
# <div id="f3003104-681a-4f1c-b7f7-3fed61e77f48" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f3003104-681a-4f1c-b7f7-3fed61e77f48", [{"mode": "lines", "name": "lines", "x": ["2007-01-03", "2007-01-04", "2007-01-05", "2007-01-08", "2007-01-09", "2007-01-10", "2007-01-11", "2007-01-12", "2007-01-16", "2007-01-17", "2007-01-18", "2007-01-19", "2007-01-22", "2007-01-23", "2007-01-24", "2007-01-25", "2007-01-26", "2007-01-29", "2007-01-30", "2007-01-31", "2007-02-01", "2007-02-02", "2007-02-05", "2007-02-06", "2007-02-07", "2007-02-08", "2007-02-09", "2007-02-12", "2007-02-13", "2007-02-14", "2007-02-15", "2007-02-16", "2007-02-20", "2007-02-21", "2007-02-22", "2007-02-23", "2007-02-26", "2007-02-27", "2007-02-28", "2007-03-01", "2007-03-02", "2007-03-05", "2007-03-06", "2007-03-07", "2007-03-08", "20
# ...
